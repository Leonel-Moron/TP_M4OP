# %%
import pandas as pd

# %%
resultados =pd.read_csv ("C:/Users/ASUS/Downloads/DATOS/ResultadosElectorales_2023_Generales.csv")
resultados.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2072\2549365865.py:1: DtypeWarning: Columns (7,10,11,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   resultados =pd.read_csv ("C:/Users/ASUS/Downloads/DATOS/ResultadosElectorales_2023_Generales.csv")
#     año eleccion_tipo recuento_tipo padron_tipo  distrito_id  \
# 0  2023       GENERAL    PROVISORIO      NORMAL            1
# 1  2023       GENERAL    PROVISORIO      NORMAL            1
# 2  2023       GENERAL    PROVISORIO      NORMAL            1
# 3  2023       GENERAL    PROVISORIO      NORMAL            1
# 4  2023       GENERAL    PROVISORIO      NORMAL            1
#
#                    distrito_nombre  seccionprovincial_id  \
# 0  Ciudad Autónoma de Buenos Aires                     0
# 1  Ciudad Autónoma de Buenos Aires                     0
# 2  Ciudad Autónoma de Buenos Aires                     0
# 3  Ciudad Autónoma de Buenos Aires                     0
# 4  Ciudad Autónoma de Buenos Aires                     0
#
#   seccionprovincial_nombre  seccion_id seccion_nombre  ... mesa_tipo  \
# 0                      NaN           1      Comuna 01  ...   NATIVOS
# 1                      NaN           1      Comuna 01  ...   NATIVOS
# 2                      NaN           1      Comuna 01  ...   NATIVOS
# 3                      NaN           1      Comuna 01  ...   NATIVOS
# 4                      NaN           1      Comuna 01  ...   NATIVOS
#
#   mesa_electores  cargo_id       cargo_nombre  agrupacion_id  \
# 0            343         1  PRESIDENTE Y VICE              0
# 1            343         1  PRESIDENTE Y VICE              0
# 2            343         1  PRESIDENTE Y VICE              0
# 3            343         1  PRESIDENTE Y VICE              0
# 4            349         1  PRESIDENTE Y VICE            134
#
#      agrupacion_nombre lista_numero  lista_nombre votos_tipo  votos_cantidad
# 0                  NaN          0.0           NaN       NULO               0
# 1                  NaN          0.0           NaN  IMPUGNADO               0
# 2                  NaN          0.0           NaN  RECURRIDO               0
# 3                  NaN          0.0           NaN    COMANDO               0
# 4  UNION POR LA PATRIA          NaN           NaN   POSITIVO              95
#
# [5 rows x 23 columns]

# %%
resultados [["agrupacion_nombre"]]
# Out:
#                                       agrupacion_nombre
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                   UNION POR LA PATRIA
# ...                                                 ...
# 5868097                                             NaN
# 5868098                             UNION POR LA PATRIA
# 5868099                            JUNTOS POR EL CAMBIO
# 5868100                              LA LIBERTAD AVANZA
# 5868101  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
#
# [5868102 rows x 1 columns]

# %%
filtro = resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires") & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE")].reset_index()

total = filtro["votos_cantidad"].sum()
dfPartidos = filtro.groupby(["agrupacion_nombre","distrito_nombre"]
    ).agg(porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))
    ).reset_index()
filtroUxP= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["agrupacion_nombre"] == "UNION POR LA PATRIA")]

filtroUxP.groupby(["seccion_nombre","agrupacion_nombre"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre    agrupacion_nombre  votos_total  porcentaje
# 0       Comuna 01  UNION POR LA PATRIA        38645        2.02
# 1       Comuna 02  UNION POR LA PATRIA        19225        1.01
# 2       Comuna 03  UNION POR LA PATRIA        38993        2.04
# 3       Comuna 04  UNION POR LA PATRIA        51401        2.69
# 4       Comuna 05  UNION POR LA PATRIA        42504        2.22
# 5       Comuna 06  UNION POR LA PATRIA        39230        2.05
# 6       Comuna 07  UNION POR LA PATRIA        44622        2.33
# 7       Comuna 08  UNION POR LA PATRIA        43136        2.26
# 8       Comuna 09  UNION POR LA PATRIA        39233        2.05
# 9       Comuna 10  UNION POR LA PATRIA        37457        1.96
# 10      Comuna 11  UNION POR LA PATRIA        41468        2.17
# 11      Comuna 12  UNION POR LA PATRIA        45856        2.40
# 12      Comuna 13  UNION POR LA PATRIA        37526        1.96
# 13      Comuna 14  UNION POR LA PATRIA        35459        1.86
# 14      Comuna 15  UNION POR LA PATRIA        46077        2.41

# %%
filtroJxc= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["agrupacion_nombre"] == "JUNTOS POR EL CAMBIO")]

filtroJxc.groupby(["seccion_nombre","agrupacion_nombre"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre     agrupacion_nombre  votos_total  porcentaje
# 0       Comuna 01  JUNTOS POR EL CAMBIO        45975        2.41
# 1       Comuna 02  JUNTOS POR EL CAMBIO        57022        2.98
# 2       Comuna 03  JUNTOS POR EL CAMBIO        39075        2.04
# 3       Comuna 04  JUNTOS POR EL CAMBIO        39963        2.09
# 4       Comuna 05  JUNTOS POR EL CAMBIO        43259        2.26
# 5       Comuna 06  JUNTOS POR EL CAMBIO        54873        2.87
# 6       Comuna 07  JUNTOS POR EL CAMBIO        48420        2.53
# 7       Comuna 08  JUNTOS POR EL CAMBIO        26068        1.36
# 8       Comuna 09  JUNTOS POR EL CAMBIO        37413        1.96
# 9       Comuna 10  JUNTOS POR EL CAMBIO        41986        2.20
# 10      Comuna 11  JUNTOS POR EL CAMBIO        54758        2.86
# 11      Comuna 12  JUNTOS POR EL CAMBIO        64831        3.39
# 12      Comuna 13  JUNTOS POR EL CAMBIO        87321        4.57
# 13      Comuna 14  JUNTOS POR EL CAMBIO        80939        4.23
# 14      Comuna 15  JUNTOS POR EL CAMBIO        45464        2.38

# %%
filtroLLA= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["agrupacion_nombre"] == "LA LIBERTAD AVANZA")]

filtroLLA.groupby(["seccion_nombre","agrupacion_nombre"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre   agrupacion_nombre  votos_total  porcentaje
# 0       Comuna 01  LA LIBERTAD AVANZA        25657        1.34
# 1       Comuna 02  LA LIBERTAD AVANZA        17875        0.94
# 2       Comuna 03  LA LIBERTAD AVANZA        23562        1.23
# 3       Comuna 04  LA LIBERTAD AVANZA        29077        1.52
# 4       Comuna 05  LA LIBERTAD AVANZA        20595        1.08
# 5       Comuna 06  LA LIBERTAD AVANZA        20043        1.05
# 6       Comuna 07  LA LIBERTAD AVANZA        28137        1.47
# 7       Comuna 08  LA LIBERTAD AVANZA        27845        1.46
# 8       Comuna 09  LA LIBERTAD AVANZA        25544        1.34
# 9       Comuna 10  LA LIBERTAD AVANZA        23062        1.21
# 10      Comuna 11  LA LIBERTAD AVANZA        25858        1.35
# 11      Comuna 12  LA LIBERTAD AVANZA        27422        1.43
# 12      Comuna 13  LA LIBERTAD AVANZA        27643        1.45
# 13      Comuna 14  LA LIBERTAD AVANZA        25920        1.36
# 14      Comuna 15  LA LIBERTAD AVANZA        21184        1.11

# %%
filtroFIT= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["agrupacion_nombre"] == "FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD")]

filtroFIT.groupby(["seccion_nombre","agrupacion_nombre"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre                               agrupacion_nombre  \
# 0       Comuna 01  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 1       Comuna 02  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 2       Comuna 03  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 3       Comuna 04  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 4       Comuna 05  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 5       Comuna 06  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 6       Comuna 07  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 7       Comuna 08  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 8       Comuna 09  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 9       Comuna 10  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 10      Comuna 11  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 11      Comuna 12  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 12      Comuna 13  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 13      Comuna 14  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 14      Comuna 15  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
#
#     votos_total  porcentaje
# 0          3981        0.21
# 1          1912        0.10
# 2          4571        0.24
# 3          5586        0.29
# 4          4814        0.25
# 5          4208        0.22
# 6          4863        0.25
# 7          4285        0.22
# 8          4578        0.24
# 9          4719        0.25
# 10         5061        0.26
# 11         5307        0.28
# 12         3887        0.20
# 13         3613        0.19
# 14         4760        0.25

# %%
filtroHXN= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["agrupacion_nombre"] == "HACEMOS POR NUESTRO PAIS")]

filtroHXN.groupby(["seccion_nombre","agrupacion_nombre"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre         agrupacion_nombre  votos_total  porcentaje
# 0       Comuna 01  HACEMOS POR NUESTRO PAIS         3230        0.17
# 1       Comuna 02  HACEMOS POR NUESTRO PAIS         2250        0.12
# 2       Comuna 03  HACEMOS POR NUESTRO PAIS         3362        0.18
# 3       Comuna 04  HACEMOS POR NUESTRO PAIS         4211        0.22
# 4       Comuna 05  HACEMOS POR NUESTRO PAIS         3675        0.19
# 5       Comuna 06  HACEMOS POR NUESTRO PAIS         3698        0.19
# 6       Comuna 07  HACEMOS POR NUESTRO PAIS         4193        0.22
# 7       Comuna 08  HACEMOS POR NUESTRO PAIS         3238        0.17
# 8       Comuna 09  HACEMOS POR NUESTRO PAIS         4047        0.21
# 9       Comuna 10  HACEMOS POR NUESTRO PAIS         4164        0.22
# 10      Comuna 11  HACEMOS POR NUESTRO PAIS         4588        0.24
# 11      Comuna 12  HACEMOS POR NUESTRO PAIS         5013        0.26
# 12      Comuna 13  HACEMOS POR NUESTRO PAIS         4321        0.23
# 13      Comuna 14  HACEMOS POR NUESTRO PAIS         3621        0.19
# 14      Comuna 15  HACEMOS POR NUESTRO PAIS         3996        0.21

# %%
filtroFIT= resultados[(resultados["distrito_nombre"]== "Ciudad Autónoma de Buenos Aires")
                      & (resultados["cargo_nombre"] == "PRESIDENTE Y VICE") 
                      & (resultados["votos_tipo"] == "EN BLANCO")]

filtroFIT.groupby(["seccion_nombre","votos_tipo"]
                 ).agg(votos_total = ("votos_cantidad", "sum"),
                      porcentaje = ("votos_cantidad", lambda x: round((x.sum()*100)/total,2))).reset_index()
# Out:
#    seccion_nombre votos_tipo  votos_total  porcentaje
# 0       Comuna 01  EN BLANCO         2456        0.13
# 1       Comuna 02  EN BLANCO         1244        0.07
# 2       Comuna 03  EN BLANCO         1798        0.09
# 3       Comuna 04  EN BLANCO         2712        0.14
# 4       Comuna 05  EN BLANCO         1860        0.10
# 5       Comuna 06  EN BLANCO         1687        0.09
# 6       Comuna 07  EN BLANCO         2410        0.13
# 7       Comuna 08  EN BLANCO         3289        0.17
# 8       Comuna 09  EN BLANCO         2054        0.11
# 9       Comuna 10  EN BLANCO         1915        0.10
# 10      Comuna 11  EN BLANCO         2191        0.11
# 11      Comuna 12  EN BLANCO         2263        0.12
# 12      Comuna 13  EN BLANCO         2390        0.13
# 13      Comuna 14  EN BLANCO         1894        0.10
# 14      Comuna 15  EN BLANCO         2148        0.11
