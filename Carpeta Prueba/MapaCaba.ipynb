# %%
import pandas as pd
import geopandas as gpd
import matplotlib as mtpl

# %%
geo = gpd.read_file("circuitos-electorales.csv")
geo.shape
# Out:
# (167, 11)

# %%
filtro = [[(geo["BARRIO"] == "SAN TELMO")]]
result = [filtro]
result
# Out:
# [[[0       True
#    1       True
#    2      False
#    3      False
#    4      False
#           ...
#    162    False
#    163    False
#    164    False
#    165    False
#    166    False
#    Name: BARRIO, Length: 167, dtype: bool]]]

# %%
geo.plot()
# Out:
# <Axes: >

# %%
geo.tail(20)
# Out:
#                                                    WKT   ID CIRCUITO_N COMUNA  \
# 147  MULTIPOLYGON (((-58.4306930411435 -34.58237617...  154        154     14
# 148  MULTIPOLYGON (((-58.4382439592238 -34.58885690...  155        155     14
# 149  MULTIPOLYGON (((-58.4300449544808 -34.59430148...  156        156     14
# 150  MULTIPOLYGON (((-58.4143902816402 -34.59406123...  157        157     14
# 151  MULTIPOLYGON (((-58.4233636058363 -34.59775318...  158        158     15
# 152  MULTIPOLYGON (((-58.4406640567006 -34.59812928...  159        159     15
# 153  MULTIPOLYGON (((-58.4321829923017 -34.60205782...  160        160     15
# 154  MULTIPOLYGON (((-58.4371689247657 -34.60454761...  161        161     15
# 155  MULTIPOLYGON (((-58.470817935025 -34.587449264...  162        162     15
# 156  MULTIPOLYGON (((-58.4385362537971 -34.58866797...  163        163     15
# 157  MULTIPOLYGON (((-58.4592333026388 -34.59668669...  164        164     15
# ...

# %%
geo.plot(column="AREA")
# Out:
# <Axes: >

# %%
geo.plot(column="BARRIO")
# Out:
# <Axes: >

# %%
geo.plot(column="COMUNA", edgecolor = "white")
# Out:
# <Axes: >

# %%
geo.centroid.plot(ax=geo.plot(color = "white", edgecolor = "blue"), color = "blue", markersize = 3 )
# Out:
# <Axes: >

# %%
geo.boundary.plot()
# Out:
# <Axes: >
